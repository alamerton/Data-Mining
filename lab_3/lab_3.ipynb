# %% [markdown]
# Generate some random data for clustering

# %%
import sklearn.datasets as data

X, clusters = data.make_blobs(n_samples=1000, n_features=2, cluster_std=1.0)

# %%
import pandas as pd

df = pd.DataFrame(X, clusters)

print(df)
# Out:
#            0         1
# 2  -6.275332  3.739852
# 2  -5.935930  3.864789
# 0   3.755952 -2.133514
# 0   0.255110 -2.190054
# 2  -5.825550  4.489395
# ..       ...       ...
# 2  -7.141608  2.226115
# 1  -8.162461 -6.050495
# 2  -7.607009  3.484826
# 1  -8.742538 -5.956085
# 1  -8.424607 -5.324097
#
# [1000 rows x 2 columns]

# %% [markdown]
# Plot synthetic data

# %%
import matplotlib.pyplot as plt

# fig, ax = plt.subplots()

plt.scatter(df[0], df[1])

# %%
k = 10
clusters = k
centres = k
converged = False
while converged !=True:
    # compute distance between clusters and centres
    # for each instance, assign it to the cluster with the closest centre
    ## check if the assignments have changed. If none, converged = true
    # compute distance again
