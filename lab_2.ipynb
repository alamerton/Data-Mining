# %% [markdown]
# ### Data Mining Lab 2

# %%
import data
import matplotlib as plt
import pandas as pd
import numpy as np

# %% [markdown]
# Convert CSV to dataframe

# %%
df = pd.read_csv("data/london-borough-profiles-jan2018.csv", encoding='unicode_escape')
df.head()
# Out:
#         Code   New code             Area name Inner/ Outer London  \
# 0        NaN        NaN                   NaN                 NaN
# 1  E09000001  E09000001        City of London        Inner London
# 2  E09000002  E09000002  Barking and Dagenham        Outer London
# 3  E09000003  E09000003                Barnet        Outer London
# 4  E09000004  E09000004                Bexley        Outer London
#
#    GLA Population Estimate 2017  GLA Household Estimate 2017  \
# 0                           NaN                          NaN
# 1                        8800.0                       5326.0
# 2                      209000.0                      78188.0
# 3                      389600.0                     151423.0
# 4                      244300.0                      97736.0
#
#   Inland Area (Hectares)  Population density (per hectare) 2017  \
# 0                    NaN                                    NaN
# 1                    290                                   30.3
# ...

# %%
print(df.columns)
# Out:
# Index(['Code', 'New code', 'Area name', 'Inner/ Outer London',
#        'GLA Population Estimate 2017', 'GLA Household Estimate 2017',
#        'Inland Area (Hectares)', 'Population density (per hectare) 2017',
#        'Average Age, 2017', 'Proportion of population aged 0-15, 2015',
#        'Proportion of population of working-age, 2015',
#        'Proportion of population aged 65 and over, 2015',
#        'Net internal migration (2015)', 'Net international migration (2015)',
#        'Net natural change (2015)',
#        '% of resident population born abroad (2015)',
#        'Largest migrant population by country of birth (2011)',
#        '% of largest migrant population (2011)',
#        'Second largest migrant population by country of birth (2011)',
#        '% of second largest migrant population (2011)',
#        'Third largest migrant population by country of birth (2011)',
#        '% of third largest migrant population (2011)',
# ...

# %% [markdown]
# Create new dataframe containing the target values

# %%
new_df = df[['Male life expectancy, (2012-14)','Female life expectancy, (2012-14)']].copy()

# %% [markdown]
# Check contents of columns of new dataset

# %%
column1 = new_df['Male life expectancy, (2012-14)']
column2 = new_df['Female life expectancy, (2012-14)']

print(column1)
print(column2)
# Out:
# 0      NaN
# 1        .
# 2     77.6
# 3     82.1
# 4     80.4
# 5     80.1
# 6     81.4
# 7     81.8
# 8     80.3
# 9     80.6
# 10    80.7
# 11      79
# 12    78.5
# 13    79.7
# 14    80.1
# 15    82.7
# 16    80.2
# 17    80.4
# 18      80
# 19      79
# 20    83.3
# 21      82
# 22    78.9
# 23      79
# 24    80.4
# 25    78.5
# 26    80.9
# 27    82.4
# 28    78.9
# 29    80.9
# 30    78.1
# 31    79.4
# 32    79.5
# 33    82.3
# Name: Male life expectancy, (2012-14), dtype: object
# 0      NaN
# 1        .
# 2     82.1
# 3     85.1
# 4     84.4
# 5     85.1
# 6     84.9
# 7     86.7
# 8     83.6
# 9     84.2
# 10    84.1
# 11    82.5
# 12    83.3
# 13    84.1
# 14    84.9
# 15    86.1
# 16    83.9
# 17    83.9
# 18    83.9
# 19    83.5
# 20    86.4
# 21    84.6
# 22    83.3
# 23    83.4
# 24    84.2
# 25      83
# 26    84.6
# 27      86
# 28    83.9
# 29    83.4
# 30    82.5
# 31    83.8
# 32    83.7
# 33    86.3
# Name: Female life expectancy, (2012-14), dtype: object

# %% [markdown]
# Remove NaN values from dataset

# %%
new_df.dropna(0)
# new_df['Male life expectancy, (2012-14)'].replace('.', '', inplace=True)
# new_df['Female life expectancy, (2012-14)'].replace('.', '', inplace=True)
new_df['Male life expectancy, (2012-14)'].replace(np.nan, '', inplace=True)
new_df['Female life expectancy, (2012-14)'].replace(np.nan, '', inplace=True)

new_df['Female life expectancy, (2012-14)'].drop('.')
new_df['Male life expectancy, (2012-14)']
new_df['Male life expectancy, (2012-14)'].drop('.')
# Out:
# C:\Users\Alfie\AppData\Local\Temp\ipykernel_26072\3307195242.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   new_df.dropna(0)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[73], line 7
#       4 new_df['Male life expectancy, (2012-14)'].replace(np.nan, '', inplace=True)
#       5 new_df['Female life expectancy, (2012-14)'].replace(np.nan, '', inplace=True)
# ----> 7 new_df['Female life expectancy, (2012-14)'].drop('.')
#       8 new_df['Male life expectancy, (2012-14)'].drop('.')
#
# File c:\Users\Alfie\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
column1 = new_df['Male life expectancy, (2012-14)']
column2 = new_df['Female life expectancy, (2012-14)']

print(column1)
print(column2)
# Out:
# 0
# 1
# 2     77.6
# 3     82.1
# 4     80.4
# 5     80.1
# 6     81.4
# 7     81.8
# 8     80.3
# 9     80.6
# 10    80.7
# 11      79
# 12    78.5
# 13    79.7
# 14    80.1
# 15    82.7
# 16    80.2
# 17    80.4
# 18      80
# 19      79
# 20    83.3
# 21      82
# 22    78.9
# 23      79
# 24    80.4
# 25    78.5
# 26    80.9
# 27    82.4
# 28    78.9
# 29    80.9
# 30    78.1
# 31    79.4
# 32    79.5
# 33    82.3
# Name: Male life expectancy, (2012-14), dtype: object
# 0
# 1
# 2     82.1
# 3     85.1
# 4     84.4
# 5     85.1
# 6     84.9
# 7     86.7
# 8     83.6
# 9     84.2
# 10    84.1
# 11    82.5
# 12    83.3
# 13    84.1
# 14    84.9
# 15    86.1
# 16    83.9
# 17    83.9
# 18    83.9
# 19    83.5
# 20    86.4
# 21    84.6
# 22    83.3
# 23    83.4
# 24    84.2
# 25      83
# 26    84.6
# 27      86
# 28    83.9
# 29    83.4
# 30    82.5
# 31    83.8
# 32    83.7
# 33    86.3
# Name: Female life expectancy, (2012-14), dtype: object

# %%
new_df['Male life expectancy, (2012-14)'] = new_df['Male life expectancy, (2012-14)'].astype(int)
new_df['Female life expectancy, (2012-14)'] = new_df['Female life expectancy, (2012-14)'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 new_df['Male life expectancy, (2012-14)'] = new_df['Male life expectancy, (2012-14)'].astype(int)
#       2 new_df['Female life expectancy, (2012-14)'] = new_df['Female life expectancy, (2012-14)'].astype(int)
#
# File c:\Users\Alfie\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# ...

# %%
new_df.plot.scatter(x = 'Male life expectancy, (2012-14)', y = 'Female life expectancy, (2012-14)')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 new_df.plot.scatter(x = 'Male life expectancy, (2012-14)', y = 'Female life expectancy, (2012-14)')
#
# File c:\Users\Alfie\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_core.py:1697, in PlotAccessor.scatter(self, x, y, s, c, **kwargs)
#    1614 def scatter(self, x, y, s=None, c=None, **kwargs) -> PlotAccessor:
#    1615     """
#    1616     Create a scatter plot with varying marker point size and color.
#    1617
#    (...)
#    1695         ...                       colormap='viridis')
#    1696     """
# -> 1697     return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#
# File c:\Users\Alfie\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_core.py:945, in PlotAccessor.__call__(self, *args, **kwargs)
# ...
